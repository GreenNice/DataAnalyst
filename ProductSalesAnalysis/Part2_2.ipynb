            [92804],[55016],[48180],[ 2908],[77520],[55125],[60068],[38134],[59715],[33407],[13440],
            [23434],[53142],[ 8861],[71901],[88001],[48310],[ 1453],[16602],[75019],[18018],[47362],
            [33317],[95928],[84043],[36830],[92404],[91360],[98042],[33065],[61761],[48911],[99207],
            [ 6360],[68701],[87401],[78501],[47150],[93454],[32114],[20016],[60477],[75002],[44221],
            [93010],[27893],[60423],[67212],[76117],[ 6040],[ 7501],[83201],[84041],[30344],[60188],
            [ 1040],[ 8360],[79109],[93309],[34952],[60035],[46614],[39401],[63122],[83704],[97756],
            [55122],[92399],[ 2740],[18103],[92563],[76021],[49423],[22901],[33319],[92253],[92374],
            [29406],[48146],[ 2169],[52001],[74012],[61107],[37130],[ 7002],[ 2138],[97123],[20852],
            [31088],[48104],[93101],[46060],[60462],[89431],[93905],[72032],[ 5401],[59601],[37087],
            [87124],[75034],[ 7960],[92530],[33024],[61821],[48126],[92704],[32303],[92592],[92627],
            [60025],[86442],[11757],[54880],[43017],[93277],[59801],[20877],[98632],[ 7090],[39503],
            [ 8401],[85635],[37421],[ 7109],[54601],[78664],[ 1810],[ 6460],[78550],[94061],[77803],
            [ 2148],[80122],[63376],[73071],[76051],[28052],[65109],[92672],[92345],[92024],[85364],
            [ 6708],[ 2886],[ 7055],[80134],[80501],[17403],[80020],[32503],[37075],[53214],[70065],
            [95616],[78539],[80525],[78577],[53081],[80112],[76706],[53186],[40324],[52402],[55106],
            [27360],[60090],[95207],[80004],[83301],[92677],[ 1752],[95695],[52240],[46350],[92630],
            [33134],[75056],[98270],[ 8302],[93405],[77301],[50322],[97405],[82001],[60004],[88220],
            [73034],[90640],[ 6484],[ 7017],[66212],[28601],[76903],[95037],[94509],[75080],[68025],
            [46142],[33030],[90503],[27534],[ 3060],[77536],[35401],[32174],[76248],[35244],[74403],
            [72756],[33068],[48237],[ 8901],[80634],[34741],[32771],[61832],[92683],[76063],[58103],
            [20707],[98226],[77489],[77581],[48307],[55369],[27514],[80022],[95610],[90660],[94403],
            [50701],[46514],[80538],[90301],[91941],[95351],[64055],[88101],[68801],[32935],[71603],
            [56301],[33023],[44060],[83642],[72762],[94086],[92236],[57401],[33458],[43123],[44035],
            [21740],[48601],[77840],[91761],[98059],[48187],[29483],[64118],[90604],[79605],[60067],
            [32127],[ 6810]]);
us_cities_flat = np.ravel(us_cities)
def generate_profit(discount_price):
# Assuming profit is a random percentage (between 10% and 30%) of the discount price
    profit_percentage = np.random.uniform(0.1, 0.3)
    return np.round(discount_price * profit_percentage,1)

# Duplicate each row in the original dataset 100 times
new_data = df.loc[df.index.repeat(100)].reset_index(drop=True)

# Update the 'id' to make them unique
new_data['id'] = new_data.index

# Add the 'profit' column with random profit values based on the discount price
new_data['profit'] = new_data['discount_price'].apply(generate_profit)

# Add the 'city' column with random US cities
new_data['city'] = np.random.choice(us_cities_flat, size=len(new_data))

# Show the new augmented dataframe
new_data
# Out:
#                 id                                               name  \
# 0                0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1                1  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 2                2  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 3                3  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 4                4  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# ...            ...                                                ...
# 55158295  55158295  Mothercare Printed Cotton Elastane Girls Infan...
# 55158296  55158296  Mothercare Printed Cotton Elastane Girls Infan...
# 55158297  55158297  Mothercare Printed Cotton Elastane Girls Infan...
# 55158298  55158298  Mothercare Printed Cotton Elastane Girls Infan...
# 55158299  55158299  Mothercare Printed Cotton Elastane Girls Infan...
#
#              main_category      sub_category  ratings  no_of_ratings  \
# ...

# %%
new_data.to_csv(r'C:\Users\Admin\Desktop\HK1_2023\BI\Midtern\Chapter2.csv', index=False)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55158300 entries, 0 to 55158299
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   name            object
#  2   main_category   object
#  3   sub_category    object
#  4   ratings         float64
#  5   no_of_ratings   int64
#  6   discount_price  float64
#  7   actual_price    float64
#  8   profit          float64
#  9   city            int32
# dtypes: float64(4), int32(1), int64(2), object(3)
# memory usage: 3.9+ GB

# %%
new_data.head()
# Out:
#    id                                               name main_category  \
# 0   0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1   1  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 2   2  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 3   3  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 4   4  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price  actual_price  \
# 0  Air Conditioners      4.2         2255.0         32999.0       58990.0
# 1  Air Conditioners      4.2         2255.0         32999.0       58990.0
# 2  Air Conditioners      4.2         2255.0         32999.0       58990.0
# 3  Air Conditioners      4.2         2255.0         32999.0       58990.0
# 4  Air Conditioners      4.2         2255.0         32999.0       58990.0
#
#    profit   city
# 0  7733.9  74133
# 1  7684.8  46350
# 2  8787.2  29464
# 3  4813.5  33317
# ...

# %%
columns_to_drop = ["name", "id", "main_category", "sub_category","city"]
dfdrop = new_data.drop(columns=columns_to_drop)

# %%
correlation_matrix = dfdrop.corr()
# Plotting the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Quantitative Variables')
plt.show()

# %%
dfdrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55158300 entries, 0 to 55158299
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   ratings         float64
#  1   no_of_ratings   int64
#  2   discount_price  float64
#  3   actual_price    float64
#  4   profit          float64
#  5   city            int32
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 2.3 GB

# %%
# Grouping by main_category and calculating mean values
category_group = new_data.groupby('main_category').mean()

# Grouping by sub_category and calculating mean values
sub_category_group = new_data.groupby('sub_category').mean()

# Grouping by city and calculating mean values
city_group = new_data.groupby('city').mean()

# Displaying the first few rows of each grouping to understand the trends
category_group.head(), sub_category_group.head(), city_group.head()

# %%
percentile_25 = df['discount_price'].quantile(0.25)
print( percentile_25)
# Out:
# Giá trị ở vị phân thứ 25 (25th percentile): 399.0

# %%
percentile_25 = df['discount_price'].quantile(0.50)
print( percentile_50)
# Out:
# Giá trị ở vị phân thứ 25 (25th percentile): 699.0

# %%
percentile_25 = df['discount_price'].quantile(0.75)
print( percentile_75)
# Out:
# Giá trị ở vị phân thứ 25 (25th percentile): 1499.0

# %%
percentile_25 = df['discount_price'].quantile(1)
print( percentile_100)
# Out:
# Giá trị ở vị phân thứ 25 (25th percentile): 1249990.0
